# %% [markdown]
# <a href="https://colab.research.google.com/github/cdixson-ds/DS-Unit-2-Applied-Modeling/blob/master/LS_DS_231_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 1*
#
# ---
#
#
# # Define ML problems
#
# You will use your portfolio project dataset for all assignments this sprint.
#
# ## Assignment
#
# Complete these tasks for your project, and document your decisions.
#
# - [ ] Choose your target. Which column in your tabular dataset will you predict?
# - [ ] Is your problem regression or classification?
# - [ ] How is your target distributed?
#     - Classification: How many classes? Are the classes imbalanced?
#     - Regression: Is the target right-skewed? If so, you may want to log transform the target.
# - [ ] Choose your evaluation metric(s).
#     - Classification: Is your majority class frequency >= 50% and < 70% ? If so, you can just use accuracy if you want. Outside that range, accuracy could be misleading. What evaluation metric will you choose, in addition to or instead of accuracy?
#     - Regression: Will you use mean absolute error, root mean squared error, R^2, or other regression metrics?
# - [ ] Choose which observations you will use to train, validate, and test your model.
#     - Are some observations outliers? Will you exclude them?
#     - Will you do a random split or a time-based split?
# - [ ] Begin to clean and explore your data.
# - [ ] Begin to choose which features, if any, to exclude. Would some features "leak" future information?
#
# If you haven't found a dataset yet, do that today. [Review requirements for your portfolio project](https://lambdaschool.github.io/ds/unit2) and choose your dataset.
#
# Some students worry, ***what if my model isn't “good”?*** Then, [produce a detailed tribute to your wrongness. That is science!](https://twitter.com/nathanwpyle/status/1176860147223867393)

# %% [markdown]
# # How can I evaluate the popularity of a genre? By rating, but also by number of movies made?

# %%
import pandas as pd

df_basic = pd.read_csv('https://datasets.imdbws.com/title.basics.tsv.gz', sep='\t', low_memory=False)

# %%
df_basic.dropna()
# Out:
#             tconst  titleType  ... runtimeMinutes                    genres
# 0        tt0000001      short  ...              1         Documentary,Short
# 1        tt0000002      short  ...              5           Animation,Short
# 2        tt0000003      short  ...              4  Animation,Comedy,Romance
# 3        tt0000004      short  ...             \N           Animation,Short
# 4        tt0000005      short  ...              1              Comedy,Short
# ...            ...        ...  ...            ...                       ...
# 6503090  tt9916848  tvEpisode  ...             \N       Action,Drama,Family
# 6503091  tt9916850  tvEpisode  ...             \N       Action,Drama,Family
# 6503092  tt9916852  tvEpisode  ...             \N       Action,Drama,Family
# 6503093  tt9916856      short  ...             27                     Short
# 6503094  tt9916880  tvEpisode  ...             10   Animation,Comedy,Family
#
# [6503073 rows x 9 columns]

# %%
df_basic.shape
# Out:
# (6503095, 9)

# %%
df_rating = pd.read_csv('https://datasets.imdbws.com/title.ratings.tsv.gz', sep='\t', low_memory=False)

# %%
df_basic.isnull().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      10
# originalTitle     10
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            12
# dtype: int64

# %%
df_basic.fillna('missing')
# Out:
#             tconst  titleType  ... startYear                    genres
# 0        tt0000001      short  ...      1894         Documentary,Short
# 1        tt0000002      short  ...      1892           Animation,Short
# 2        tt0000003      short  ...      1892  Animation,Comedy,Romance
# 3        tt0000004      short  ...      1892           Animation,Short
# 4        tt0000005      short  ...      1893              Comedy,Short
# ...            ...        ...  ...       ...                       ...
# 6503090  tt9916848  tvEpisode  ...      2010       Action,Drama,Family
# 6503091  tt9916850  tvEpisode  ...      2010       Action,Drama,Family
# 6503092  tt9916852  tvEpisode  ...      2010       Action,Drama,Family
# 6503093  tt9916856      short  ...      2015                     Short
# 6503094  tt9916880  tvEpisode  ...      2014   Animation,Comedy,Family
#
# [6503095 rows x 5 columns]

# %%
df_basic.isnull().sum()
# Out:
# tconst           0
# titleType        0
# primaryTitle    10
# startYear        0
# genres          12
# dtype: int64

# %% [markdown]
# I did some exploration on the IMDb website to make sure these ratings were associated with the tconst and movie from the other dataset

# %%
df_rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1578
# 1  tt0000002            6.1       189
# 2  tt0000003            6.5      1242
# 3  tt0000004            6.2       117
# 4  tt0000005            6.1      1985

# %%
df_rating.shape
# Out:
# (1019087, 3)

# %%
df_basic = df_basic.drop(columns=['originalTitle', 'isAdult', 'originalTitle','runtimeMinutes', 'endYear'])

# %%
pd.set_option('display.max_rows', None)  
df_basic.head(100)
# Out:
#        tconst titleType                                       primaryTitle  \
# 0   tt0000001     short                                         Carmencita
# 1   tt0000002     short                             Le clown et ses chiens
# 2   tt0000003     short                                     Pauvre Pierrot
# 3   tt0000004     short                                        Un bon bock
# 4   tt0000005     short                                   Blacksmith Scene
# 5   tt0000006     short                                  Chinese Opium Den
# 6   tt0000007     short        Corbett and Courtney Before the Kinetograph
# 7   tt0000008     short             Edison Kinetoscopic Record of a Sneeze
# 8   tt0000009     movie                                         Miss Jerry
# 9   tt0000010     short                                Exiting the Factory
# 10  tt0000011     short                            Akrobatisches Potpourri
# 11  tt0000012     short                             The Arrival of a Train
# 12  tt0000013     short        The Photographical Congress Arrives in Lyon
# 13  tt0000014     short                            The Sprinkler Sprinkled
# 14  tt0000015     short                                Autour d'une cabine
# 15  tt0000016     short                             Barque sortant du port
# 16  tt0000017     short                           Italienischer Bauerntanz
# 17  tt0000018     short                               Das boxende Känguruh
# 18  tt0000019     short                                   The Clown Barber
# 19  tt0000020     short                                     The Derby 1895
# 20  tt0000022     short                                   Blacksmith Scene
# 21  tt0000023     short                                            The Sea
# 22  tt0000024     short                          Opening of the Kiel Canal
# 23  tt0000025     short      The Oxford and Cambridge University Boat Race
# 24  tt0000026     short                      The Messers. Lumière at Cards
# 25  tt0000027     short                         Cordeliers' Square in Lyon
# 26  tt0000028     short                               Fishing for Goldfish
# 27  tt0000029     short                                      Baby's Dinner
# 28  tt0000030     short                                 Rough Sea at Dover
# 29  tt0000031     short                                Jumping the Blanket
# 30  tt0000032     short                              Die Serpentintänzerin
# 31  tt0000033     short                                       Trick Riding
# 32  tt0000034     short               Arrivée d'un train gare de Vincennes
# 33  tt0000035     short                               Watering the Flowers
# 34  tt0000036     short                                   Awakening of Rip
# 35  tt0000037     short                                        Sea Bathing
# 36  tt0000038     short                                      The Ball Game
# 37  tt0000039     short                                  Barnet Horse Fair
# 38  tt0000040     short                Barque sortant du port de Trouville
# 39  tt0000041     short                                  Bataille de neige
# 40  tt0000042     short                         Bateau-mouche sur la Seine
# 41  tt0000043     short                                  Batteuse à vapeur
# 42  tt0000044     short                                         Le bivouac
# 43  tt0000045     short                                 Les blanchisseuses
# 44  tt0000046     short                                   Bois de Boulogne
# 45  tt0000047     short                             Boulevard des Italiens
# 46  tt0000048     short                                The Boxing Kangaroo
# 47  tt0000049     short                    Boxing Match; or, Glove Contest
# 48  tt0000050     short                                  Bébé et fillettes
# 49  tt0000051     short                            The Bohemian Encampment
# 50  tt0000052     short                                   Carga de rurales
# 51  tt0000053     short  A Chegada do Comboio Inaugural à Estação Centr...
# 52  tt0000054     short                                   A Merry-Go-Round
# 53  tt0000055     short                                     Le chiffonnier
# 54  tt0000056     short             Uma Corrida de Touros no Campo Pequeno
# 55  tt0000057     short                Cortège de tzar allant à Versailles
# 56  tt0000058     short                Cortège de tzar au Bois de Boulogne
# 57  tt0000059     short                     Coronation of a Village Maiden
# 58  tt0000060     short                                    Dancing Darkies
# 59  tt0000061     short                                      Dancing Girls
# 60  tt0000062     short                                   Danse serpentine
# 61  tt0000063     short                                Dessinateur express
# 62  tt0000064     short                           Dessinateur: Chamberlain
# 63  tt0000065     short                        Dessinateur: Reine Victoria
# 64  tt0000066     short                           Dessinateur: Von Bismark
# 65  tt0000067     short          Conjurer Making Ten Hats in Sixty Seconds
# 66  tt0000068     short                                 Unloading the Boat
# 67  tt0000069     short                                      Post No Bills
# 68  tt0000070     short                                Démolition d'un mur
# 69  tt0000071     short                        Automobiles Starting a Race
# 70  tt0000072     short            Officers of French Army Leaving Service
# 71  tt0000073     short                      Effets de mer sur les rochers
# 72  tt0000074     short                        Enfants jouant sur la plage
# 73  tt0000075     short  The Conjuring of a Woman at the House of Rober...
# 74  tt0000076     short                          Exit of Rip and the Dwarf
# 75  tt0000077     short                           Le fakir, mystère indien
# 76  tt0000078     short                         Feira de Gado na Corujeira
# 77  tt0000079     short                               La gare Saint-Lazare
# 78  tt0000080     short                                 Grandes manoeuvres
# 79  tt0000081     short                         Towing a Boat on the River
# 80  tt0000082     short                                        A Hard Wash
# 81  tt0000083     short                                     Les indiscrets
# 82  tt0000084     short                                       Les ivrognes
# 83  tt0000085     short                             Gardener Burning Weeds
# 84  tt0000086     short              Beach and Pier at Trouville, 1st part
# 85  tt0000087     short              Beach and Pier at Trouville, 2nd part
# 86  tt0000088     short                                         Market Day
# 87  tt0000089     short                       Leaving Jerusalem by Railway
# 88  tt0000090     short                        Libération des territoriaux
# 89  tt0000091     short                             The House of the Devil
# 90  tt0000092     short                    Marée montante sur Brise-Larmes
# 91  tt0000093     short                                          Melbourne
# 92  tt0000094     short                                       Miss de Vere
# 93  tt0000095     short                               The Mysterious Paper
# 94  tt0000096     short                               Place Saint-Augustin
# 95  tt0000097     short                       Place de l'Opéra, First View
# 96  tt0000098     short                      Place de l'Opéra, Second View
# 97  tt0000099     short                               Place de la Bastille
# 98  tt0000100     short                               Place de la Concorde
# 99  tt0000101     short                          Place du théâtre français
#
#    startYear                     genres
# 0       1894          Documentary,Short
# 1       1892            Animation,Short
# 2       1892   Animation,Comedy,Romance
# 3       1892            Animation,Short
# 4       1893               Comedy,Short
# 5       1894                      Short
# 6       1894                Short,Sport
# 7       1894          Documentary,Short
# 8       1894                    Romance
# 9       1895          Documentary,Short
# 10      1895          Documentary,Short
# 11      1896   Action,Documentary,Short
# 12      1895          Documentary,Short
# 13      1895               Comedy,Short
# 14      1894            Animation,Short
# 15      1895          Documentary,Short
# 16      1895          Documentary,Short
# 17      1895                      Short
# 18      1898               Comedy,Short
# 19      1895    Documentary,Short,Sport
# 20      1895          Documentary,Short
# 21      1895          Documentary,Short
# 22      1895                 News,Short
# 23      1895           News,Short,Sport
# 24      1896          Documentary,Short
# 25      1895          Documentary,Short
# 26      1895          Documentary,Short
# 27      1895          Documentary,Short
# 28      1895          Documentary,Short
# 29      1895          Documentary,Short
# 30      1895                      Short
# 31      1895   Comedy,Documentary,Short
# 32      1896          Documentary,Short
# 33      1896               Comedy,Short
# 34      1896                Drama,Short
# 35      1896                      Short
# 36      1898    Documentary,Short,Sport
# 37      1896                      Short
# 38      1896          Documentary,Short
# 39      1897  Action,Comedy,Documentary
# 40      1896          Documentary,Short
# 41      1896          Documentary,Short
# 42      1896                      Short
# 43      1896                      Short
# 44      1896          Documentary,Short
# 45      1896          Documentary,Short
# 46      1896                      Short
# 47      1896                Short,Sport
# 48      1896          Documentary,Short
# 49      1896          Documentary,Short
# 50      1896          Documentary,Short
# 51      1897          Documentary,Short
# 52      1896                      Short
# 53      1896                      Short
# 54      1896                      Short
# 55      1896          Documentary,Short
# 56      1896          Documentary,Short
# 57      1896                      Short
# 58      1896          Documentary,Short
# 59      1896                      Short
# 60      1896                      Short
# 61      1896                      Short
# 62      1896                      Short
# 63      1896                      Short
# 64      1896                      Short
# 65      1896              Fantasy,Short
# 66      1896          Documentary,Short
# 67      1896                      Short
# 68      1896          Documentary,Short
# 69      1896                Short,Sport
# 70      1896                      Short
# 71      1896          Documentary,Short
# 72      1896          Documentary,Short
# 73      1896               Horror,Short
# 74      1896                Drama,Short
# 75      1896                      Short
# 76      1896          Documentary,Short
# 77      1896          Documentary,Short
# 78      1896          Documentary,Short
# 79      1896          Documentary,Short
# 80      1896               Comedy,Short
# 81      1896                      Short
# 82      1896                      Short
# 83      1896                      Short
# 84      1896          Documentary,Short
# 85      1896          Documentary,Short
# 86      1896          Documentary,Short
# 87      1897          Documentary,Short
# 88      1896          Documentary,Short
# 89      1896               Horror,Short
# 90      1896          Documentary,Short
# 91      1896          Documentary,Short
# 92      1896                      Short
# 93      1896                      Short
# 94      1896          Documentary,Short
# 95      1896          Documentary,Short
# 96      1896          Documentary,Short
# 97      1896          Documentary,Short
# 98      1896          Documentary,Short
# 99      1896          Documentary,Short

# %%
df_basic.tail()
# Out:
#             tconst  titleType  ... startYear                   genres
# 6503090  tt9916848  tvEpisode  ...      2010      Action,Drama,Family
# 6503091  tt9916850  tvEpisode  ...      2010      Action,Drama,Family
# 6503092  tt9916852  tvEpisode  ...      2010      Action,Drama,Family
# 6503093  tt9916856      short  ...      2015                    Short
# 6503094  tt9916880  tvEpisode  ...      2014  Animation,Comedy,Family
#
# [5 rows x 5 columns]

# %%
df_basic['genres'].nunique()
# Out:
# 2241

# %%
#Because of how many genres are attributed to each title, I am going to need to sort
#these better

df_basic['genres'].unique()
# Out:
# array(['Documentary,Short', 'Animation,Short', 'Animation,Comedy,Romance',
#        ..., 'Musical,Reality-TV,Talk-Show', 'Animation,Short,Talk-Show',
#        'Comedy,Mystery,Talk-Show'], dtype=object)

# %%
df_basic['genres'].value_counts()
# Out:
# Drama                       641201
# \N                          511417
# Comedy                      474100
# Documentary                 318057
# Talk-Show                   318005
#                              ...
# Romance,Sport,Western            1
# Crime,Sci-Fi,War                 1
# Adventure,News,Talk-Show         1
# Biography,Crime,Sport            1
# Horror,Romance,Western           1
# Name: genres, Length: 2241, dtype: int64

# %%
#Only going to keep the movie tag

df_basic['titleType'].value_counts()
# Out:
# tvEpisode       4594463
# short            721520
# movie            542068
# video            253057
# tvSeries         177916
# tvMovie          120767
# tvMiniSeries      29204
# tvSpecial         27308
# videoGame         24933
# tvShort           11859
# Name: titleType, dtype: int64

# %% [markdown]
# The values I want to track are:
#
# Drama, Comedy, Documentary, Romance, Family, Animation, Crime, Action, Adventure, Mystery, Musical, Thriller, Horror, Sci-Fi, Fantasy, War, Western, Film-Noir, History, Sport, Biography, War, Documentary

# %%
df_basic['genres'] = df_basic['genres'].str.lower()

# %%
drama = df_basic['genres'].str.contains('drama')
comedy = df_basic['genres'].str.contains('comedy')
documentary = df_basic['genres'].str.contains('documentary')
romance = df_basic['genres'].str.contains('romance')
family = df_basic['genres'].str.contains('family')
animation = df_basic['genres'].str.contains('animation')
crime = df_basic['genres'].str.contains('crime')
action = df_basic['genres'].str.contains('action')
adventure = df_basic['genres'].str.contains('adventure')
mystery = df_basic['genres'].str.contains('mystery')
musical = df_basic['genres'].str.contains('musical')
thriller = df_basic['genres'].str.contains('thriller')
horror = df_basic['genres'].str.contains('horror')
sci_fi = df_basic['genres'].str.contains('sci')
fantasy = df_basic['genres'].str.contains('fantasy')
war = df_basic['genres'].str.contains('war')
western = df_basic['genres'].str.contains('western')
film_noir = df_basic['genres'].str.contains('film')
mystery = df_basic['genres'].str.contains('mystery')
history = df_basic['genres'].str.contains('history')
sport = df_basic['genres'].str.contains('sport')
biography = df_basic['genres'].str.contains('biography')

# %%
df_basic.isna().sum()
# Out:
# tconst           0
# titleType        0
# primaryTitle    10
# startYear        0
# genres          12
# dtype: int64

# %%
df_basic.loc[drama, 'genres'] = 'drama'
